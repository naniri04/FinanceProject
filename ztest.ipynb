# %%
import csv
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
CSV_URL = 'https://www.alphavantage.co/query?function=LISTING_STATUS&date=2014-07-10&apikey=G2EXT10EAQDEGJUW'

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)
    for row in my_list:
        print(row)
# Out:
# ['symbol', 'name', 'exchange', 'assetType', 'ipoDate', 'delistingDate', 'status']
# ['A', 'Agilent Technologies Inc', 'NYSE', 'Stock', '1999-11-18', 'null', 'Active']
# ['AABA', 'Altaba Inc', 'NASDAQ', 'Stock', '1996-04-12', 'null', 'Active']
# ['AACG', 'ATA Creativity Global', 'NASDAQ', 'Stock', '2008-01-29', 'null', 'Active']
# ['AADR', 'ADVISORSHARES DORSEY WRIGHT ADR ETF ', 'NASDAQ', 'ETF', '2010-07-21', 'null', 'Active']
# ['AAIC', 'Arlington Asset Investment Corp - Class A', 'NYSE', 'Stock', '1997-12-23', 'null', 'Active']
# ['AAIT', 'ISHARES MSCI ALL COUNTRY ASIA INFORMATION TECHNOLOGY INDEX FUND', 'NASDAQ', 'ETF', '2012-02-09', 'null', 'Active']
# ['AAL', 'American Airlines Group Inc', 'NASDAQ', 'Stock', '2005-09-27', 'null', 'Active']
# ['AAME', 'Atlantic American Corp', 'NASDAQ', 'Stock', '1984-09-07', 'null', 'Active']
# ['AAOI', 'Applied Optoelectronics Inc', 'NASDAQ', 'Stock', '2013-09-26', 'null', 'Active']
# ...

# %%
t = set()
for i in my_list:
  t.add(i[2])

# %%
t
# Out:
# {'BATS', 'NASDAQ', 'NYSE', 'NYSE ARCA', 'NYSE MKT', 'exchange'}

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=000002.SHZ&interval=5min&apikey=G2EXT10EAQDEGJUW'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_INTRADAY.'}
